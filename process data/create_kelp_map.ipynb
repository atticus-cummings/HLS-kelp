# %%
import sys
if r'C:\Users\attic\HLS Kelp Detection\tools' not in sys.path:
    sys.path.append(r'C:\Users\attic\HLS Kelp Detection\tools')
import data_tools as dt
import os

# %%
path = r'C:\Users\attic\HLS Kelp Detection\processed imagery\tiles'
tiles = ['10UCU']
kelp_pixel_threshold = 5
show_image = True
save_image = True

# %%
for tile in tiles:
    kelp_map = dt.generate_binary_kelp_map(tile,version=0, save=save_image, binary_threshold=kelp_pixel_threshold,show_image=show_image)
# Out:
# 275/275
# (1, 3660, 3660)
# HLS.L30.T10UCU.2017136T191314.v2.0.tif
# saved to: C:\Users\attic\HLS Kelp Detection\processed imagery\tiles\10UCU\kelp_map.tif
